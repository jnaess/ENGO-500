# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-ec3d520328fd> in <module>
#       1 from manager import Manager
#       2
# ----> 3 manager = Manager()
#       4
#       5 manager.plot_a()
#
# ~\Desktop\ENGO500\ENGO-500\manager.py in __init__(self)
#      23         Plotter.__init__(self)
#      24
# ---> 25         self.retrieve_sim_data()
#      26         self.initialize_simulator()
#      27         self.initialize_error_detector()
#
# ~\Desktop\ENGO500\ENGO-500\manager.py in retrieve_sim_data(self, sim_id)
#      35         Output:
#      36         """
# ---> 37         con = self.engine.connect()
#      38
#      39         self.sim_df= pd.DataFrame(self.select_all(con=con, table = 'simulations'))
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in connect(self, close_with_result)
#    3232         """
#    3233
# ...

# %%
# Out:
# Epochs Processed: 40: 100%|██████████| 40/40 [00:00<00:00, 508.01it/s]

# %%
from manager import Manager

manager = Manager()

manager.plot_a()
manager.plot_b()
manager.plot_c()
manager.plot_d()
manager.plot_e()
manager.plot_f()
# Out:
# Epochs Processed: 40: 100%|██████████| 40/40 [00:00<00:00, 163.63it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ec3d520328fd> in <module>
#       4
#       5 manager.plot_a()
# ----> 6 manager.plot_b()
#       7 manager.plot_c()
#       8 manager.plot_d()
#
# ~\Desktop\ENGO500\ENGO-500\plotter.py in plot_b(self)
#      59         Output:
#      60         """
# ---> 61         self.plot_gdf(shapes = [self.Sim.zero_pass],
#      62                       shape_colors = ['darkgray'],
#      63                       x_label = "Easting",
#
# ~\Desktop\ENGO500\ENGO-500\basePlot.py in plot_gdf(self, shapes, shape_colors, x_label, y_label, title)
#      88                 legend_kwds={'bbox_to_anchor': (1.23, 1)})
#      89         plt.xlim(0, 12)
# ---> 90         ply.ylim(0, 0)
#      91         plt.show()
#      92
#
# NameError: name 'ply' is not defined
