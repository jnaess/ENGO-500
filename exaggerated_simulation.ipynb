# %%
from manager import Manager
from point import Coord

manager = Manager(field = [[0,0],[0,20],[20,20],[20,0]],
                use_drift = True, 
                 use_jump = True, 
                 easting_drift_const = .01,
                 northing_drift_const = .01,
                 mean_jump = Coord(0,0,std = [.05, .05]),
                 jump_occurance_probability = 500,
                 drift_variability = Coord(0,0, std = [.001, .001]),
                 easting_jump_const = .2,
                 northing_jump_const = .2,
                 tractor_speed = 1, 
                 epoch_frequency = 1, 
                 rename_keys = ["epoch", "real_e"
                                , "real_n", "real_e_std", "real_n_std"], 
                 is_static = False, 
                 true_std = [.1,.1],
                tractor_width = 1.5,
                 display = True)
# Out:
# is_static --> False
# Epochs Processed: 96: 100%|███████████████████████████████████████████████████████████| 96/96 [00:00<00:00, 617.21it/s]
