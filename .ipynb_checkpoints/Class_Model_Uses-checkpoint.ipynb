# %%
from classes import *

p = Polygon()
pnt = Point(1,1)

p.test_point(pnt)

p.get_intersect()

p.new_par_line()


p = Polygon([Point(0,0), Point(0,10), Point(10,10), Point(10,0)])
pnt = Point(1,1)

p.test_point(pnt)

p.plot()

# %%
from classes import *
        
pf = PathFollower(Point(0,0), Point(1,10))

pf.segment()

pf.plot()
