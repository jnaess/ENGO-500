# %%
from manager import Manager
from point import Coord

manager = Manager(mean_jump = Coord(0,0, std = [.01, .01]),
                  jump_occurance_probability = 500,
                  easting_jump_const = .1,
                  northing_jump_const = .1)

manager.df_sim.head()["drift_cumulative_e"]
manager.df_sim.head()
# Out:
# is_static --> False
# Epochs Processed: 40: 100%|███████████████████████████████████████████████████████████| 40/40 [00:00<00:00, 691.49it/s]
#    true_e  true_n  true_e_std  true_n_std    real_e    real_n  real_e_std  \
# 0     1.5    2.25        0.01        0.01  1.500000  2.250000        0.01
# 1     2.5    2.25        0.01        0.01  2.501086  2.250863        0.01
# 2     3.5    2.25        0.01        0.01  3.502056  2.251777        0.01
# 3     4.5    2.25        0.01        0.01  4.503127  2.252854        0.01
# 4     5.5    2.25        0.01        0.01  5.504169  2.253895        0.01
#
#    real_n_std  jump_status  jump_individual_e  ...  \
# 0        0.01        False                  0  ...
# 1        0.01        False                  0  ...
# 2        0.01        False                  0  ...
# 3        0.01        False                  0  ...
# 4        0.01        False                  0  ...
#
#    drift_absolute_cumulative_e  drift_absolute_cumulative_n  error_status  \
# 0                     0.000000                     0.000000          True
# 1                     0.001086                     0.000863          True
# 2                     0.002056                     0.001777          True
# 3                     0.003127                     0.002854          True
# 4                     0.004169                     0.003895          True
#
#    error_individual_e  error_individual_n  error_cumulative_e  \
# 0            0.000000            0.000000            0.000000
# 1            0.001086            0.000863            0.001086
# 2            0.000970            0.000914            0.002056
# 3            0.001071            0.001077            0.003127
# 4            0.001042            0.001040            0.004169
#
#    error_cumulative_n  error_absolute_cumulative_e  \
# 0            0.000000                     0.000000
# 1            0.000863                     0.001086
# 2            0.001777                     0.002056
# 3            0.002854                     0.003127
# 4            0.003895                     0.004169
#
#    error_absolute_cumulative_n  epoch
# 0                     0.000000      0
# 1                     0.000863      1
# 2                     0.001777      2
# 3                     0.002854      3
# 4                     0.003895      4
#
# [5 rows x 30 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np

x = manager.df_sim.index.to_list()
y = manager.df_sim.drift_cumulative_n.to_list()
    
#create ofset lines
offsets = []
#for i in range(len(x)):
offsets.append(np.ones(len(x))*0)

x1 = manager.df_ED.index.to_list()
y1 = manager.df_ED.drift_cumulative_n.to_list()

fig = plt.figure(figsize = (8,8))

offsets.append(np.ones(len(x))*1)
            
        #fig, ax = plt.subplots()
        
ax = plt.axes(projection='3d')
        
        # Colour outside axes
        #fig.patch.set_facecolor('xkcd:light grey')

#self.set_parameters(ax, x_label, y_label, title, aspect = aspect)

#for i in range(len(x)):
#    ax.plot3D(x[i],y[i], offsets[i], label = line_label[i])
ax.plot3D(offsets[0], x,y) 


ax.plot3D(offsets[1], x1,y1) 

        
#plt.subplots_adjust(left=0, bottom=0, right=1, top=1, wspace=0, hspace=0)
        
        # Set plot limits
        #plt.xlim(0, 12)
        #plt.ylim(0, 12)
        
#elf.set_legend(anchor)
        
ax.view_init(10, 5)
plt.draw()
#plt.show() 
#manager.plot_i()

# %%
manager.plot_h()
# Out:
# '...'

# %%
manager.plot_a()
manager.plot_b()
manager.plot_c()
manager.plot_d()
manager.plot_e()
manager.plot_f()
#manager.df_sim

# %%
manager.plot_b()

# %%
manager.Sim.single_pass.columns
# Out:
# Index(['color', 'geometry', 'title'], dtype='object')

# %%
manager.Sim.double_pass.plot()
# Out:
# <AxesSubplot:>

# %%
manager.Sim.temp.plot()
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
#manager.Sim.inner.plot(ax=ax)
manager.Sim.inner_gdf.plot(ax=ax, color='#49e37c')
#manager.Sim.temp.plot(ax=ax, color='red')
manager.Sim.zero_pass.plot(ax=ax)
manager.Sim.single_pass.plot(ax=ax, color = '#915ebd')
manager.Sim.double_pass.plot(ax=ax, color = '#bd7b5e')
# Out:
# <AxesSubplot:>

# %%
manager.Sim.inner_gdf.plot()
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt

x_label="x_label"
y_label="y_label"
title="title"

fig, ax = plt.subplots()

fig.patch.set_facecolor('xkcd:mint green')


ax.set_ylabel(y_label)
ax.set_xlabel(x_label)
ax.set_title(title)

ax.set_facecolor("yellow")

manager.Sim.T_gdf_pt.plot(ax=ax)
manager.Sim.R_gdf_pt.plot(ax=ax)

plt.subplots_adjust(left=0, bottom=0, right=1, top=1, wspace=0, hspace=0)

legend = plt.legend(frameon = 1)
frame = legend.get_frame()
frame.set_facecolor('purple')
frame.set_edgecolor('white')
frame.set_linewidth(0)
        
plt.show()
        

        ##ax.set_aspect('equal')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 18>()
#      14 ax.set_title(title)
#      16 ax.set_facecolor("yellow")
# ---> 18 manager.Sim.T_gdf_pt.plot(ax=ax)
#      19 manager.Sim.R_gdf_pt.plot(ax=ax)
#      21 plt.subplots_adjust(left=0, bottom=0, right=1, top=1, wspace=0, hspace=0)
#
# NameError: name 'manager' is not defined

# %%
from manager import Manager

manager = Manager()
sim = manager.Sim
df = sim.output_tracks

# %%
# Out:
# 20

# %%
from positionGenerator import PositionGenerator as PG
from point import Coord
pg = PG(Coord(.2,.2,std = [0, 0]))

# %%
pg.generate_one()
pg.unique_pnt
# Out:
# [0.2, 0.2]

# %%
from random import randint

for i in range(100):
    print(randint(1,5))
# Out:
# 3
# 5
# 1
# 4
# 2
# 2
# 1
# 4
# 4
# 2
# 3
# 4
# 3
# 1
# 2
# 1
# 5
# 4
# 2
# 3
# 5
# 1
# 1
# 3
# 3
# 3
# 3
# 4
# 1
# 2
# 1
# 3
# 3
# 4
# 3
# 1
# 3
# 4
# 4
# 4
# 3
# 5
# 3
# 2
# 2
# 3
# 5
# 4
# 2
# 3
# 2
# 2
# 5
# 1
# 4
# 5
# 5
# 5
# 4
# 5
# 5
# 3
# 1
# 3
# 2
# 5
# 3
# 1
# 2
# 1
# 5
# 5
# 1
# 1
# 3
# 4
# 4
# 2
# 5
# 4
# 1
# 3
# 4
# 3
# 2
# 3
# 3
# 4
# 1
# 3
# 1
# 2
# 1
# 1
# 2
# 5
# 5
# 2
# 2
# 2
