# %%
import psycopg2
from sqlalchemy import create_engine
import pandas as pd

data = {'bottom_left_e' : [0],
                   'bottom_left_n' : [0],
                   'bottom_right_e' : [0],
                   'bottom_right_n' : [0],
                   'top_left_e' : [0],
                   'top_left_n' : [0],
                   'top_right_e' : [0],
                   'top_right_n' : [0],
                   'coord_system' : ["hiii"]}

df = pd.DataFrame.from_dict(data)

server = 'ec2-52-3-60-53.compute-1.amazonaws.com' 
database = 'd3kr6lkene46qr' 
username = 'mnonspcirnraqg' 
password = '7919dd02f614cb83509e2889ec281800889dec45fb24c57db99d632e678f5626' 


engine = create_engine(f'postgresql+psycopg2://{username}:{password}@{server}/{database}')
con = engine.connect()
df.to_sql('simulations', con=con, if_exists='append', index=False)
con.close()

# %%
from classes import *
        
#simulation id for accessing data from database
sim_id = 2

#coordinates
field = [[0,0],[0,10],[10,10],[10,0]]

#generates simulation tracks
Sim = Simulator(field, use_drift=True, easting_drift_const = .01, northing_drift_const = .01)

#generates dataframe of values
Sim.generate_output_tracks()

# %%
#stores dataframe of values in a variable
df_sim = Sim.output_tracks

#convert index to epochs
df_sim["epoch"] = list(df_sim.index.values)

#get key values as lists to be passed in
std = [df_sim['true_e_std'].to_list(),df_sim['true_n_std'].to_list()]
tru_N = df_sim['true_n'].to_list()
tru_E = df_sim['true_e'].to_list()
rename_keys = ["epoch", "real_e", "real_n", "real_e_std", "real_n_std"]

#run error detector simulation
ED = ErrorDetector(df_sim, tru_E, tru_N, rename_keys = rename_keys, true_std = std, is_static=False)

#store error detector values as a dataframe
ED.generate_error_dataframe()

#store error_detector values
df_err_jump = ED.jump_df
df_err_drift = ED.drift_df
df_err_errors = ED.errors_df
# Out:
# Epochs Processed: 48: 100%|███████████████████████████████████████████████████████████| 48/48 [00:00<00:00, 264.13it/s]

# %%
#prepare the final parts of the dataframe
df_err_jump["sim_id"] = np.ones(len(df_err_jump.index))*sim_id
df_err_jump["epoch"] = list(df_err_jump.index.values)

df_err_jump["jump_status"] = df_err_jump["jump_status"].astype('bool')
#arr = np.where(arr >= 1, True, arr)
#df_err_jump

# %%
import psycopg2
from sqlalchemy import create_engine

#connect to server and send data
server = 'ec2-52-3-60-53.compute-1.amazonaws.com' 
database = 'd3kr6lkene46qr' 
username = 'mnonspcirnraqg' 
password = '7919dd02f614cb83509e2889ec281800889dec45fb24c57db99d632e678f5626' 


engine = create_engine(f'postgresql+psycopg2://{username}:{password}@{server}/{database}')
con = engine.connect()

#push it to the database
#df_err_jump.to_sql('error_detector_jumps', con=con, if_exists='append', index=False)

con.close()

# %%
#withdraw from the database
engine = create_engine(f'postgresql+psycopg2://{username}:{password}@{server}/{database}')
con = engine.connect()

table = "error_detector_jumps"
SQL_Query = pd.read_sql_query(
f'''SELECT
    *
 FROM {table}
 WHERE sim_id = 2''', con)

#list of the columns withdrawn
cols = list(df_err_jump.columns)

#push it to the database
df_new = pd.DataFrame(SQL_Query, columns=cols)

con.close()

# %%
df_new
# Out:
#     jump_status  jump_individual_e  jump_individual_n  jump_cumulative_e  \
# 0          True       0.000000e+00       0.000000e+00           0.000000
# 1          True       1.538814e-02       2.861788e-02           0.015388
# 2          True       2.216813e-02       1.116779e-02           0.037556
# 3          True       3.206470e-02       9.256950e-03           0.069621
# 4          True       1.678840e-02       5.321327e-03           0.086409
# 5          True      -8.387782e-03       1.977467e-02           0.078022
# 6          True       2.508976e-02       1.224915e-02           0.103111
# 7          True       3.488273e-02       6.954267e-03           0.137994
# 8          True       1.776357e-15       4.440892e-16           0.137994
# 9          True       2.965483e-02       2.607815e-04           0.167649
# 10         True       1.189137e-02       2.917604e-02           0.179540
# 11         True       1.372433e-02       1.438977e-02           0.193265
# ...
