# %%
from manager import Manager
from point import Coord

manager = Manager(field = [[0,0],[0,100],[100,100],[100,0]],
                use_drift = True, 
                 use_jump = True, 
                 easting_drift_const = .01,
                 northing_drift_const = .01,
                 mean_jump = Coord(0,0,std = [.05, .05]),
                 jump_occurance_probability = 5,
                 drift_variability = Coord(0,0, std = [.001, .001]),
                 easting_jump_const = .2,
                 northing_jump_const = .2,
                 tractor_speed = 1, 
                 epoch_frequency = 1, 
                 rename_keys = ["epoch", "real_e", "real_n", "real_e_std", "real_n_std"], 
                 is_static = False, 
                 true_std = [.1,.1],
                tractor_width = 3)

manager.df_sim.head()["drift_cumulative_e"].to_numpy()
#manager.df_sim.head()
#manager.generate_error_detection_report()
manager.plot_a()
manager.plot_b()
manager.plot_c()
manager.plot_d()
manager.plot_e()
manager.plot_f()
# Out:
# is_static --> False
# Epochs Processed: 10: 100%|███████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 362.31it/s]

# %%
manager.plot_t()
# Out:
# '...'

# %%
import matplotlib.pyplot as plt
import numpy as np

x = manager.df_sim.index.to_list()
y = manager.df_sim.drift_cumulative_n.to_list()
    
#create ofset lines
offsets = []
#for i in range(len(x)):
offsets.append(np.ones(len(x))*0)

x1 = manager.df_ED.index.to_list()
y1 = manager.df_ED.drift_cumulative_n.to_list()

fig = plt.figure(figsize = (8,8))

offsets.append(np.ones(len(x))*1)
            
        #fig, ax = plt.subplots()
        
ax = plt.axes(projection='3d')
        
        # Colour outside axes
        #fig.patch.set_facecolor('xkcd:light grey')

#self.set_parameters(ax, x_label, y_label, title, aspect = aspect)

#for i in range(len(x)):
#    ax.plot3D(x[i],y[i], offsets[i], label = line_label[i])
ax.plot3D(offsets[0], x,y) 


ax.plot3D(offsets[1], x1,y1) 

        
#plt.subplots_adjust(left=0, bottom=0, right=1, top=1, wspace=0, hspace=0)
        
        # Set plot limits
        #plt.xlim(0, 12)
        #plt.ylim(0, 12)
        
#elf.set_legend(anchor)
        
ax.view_init(2, -1)
plt.draw()
#plt.show() 
#manager.plot_i()

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 manager.plot_i()
#
# File ~\Winter2022\Software_Build\ENGO-500\plotter.py:219, in Plotter.plot_i(self)
#     211 def plot_i(self):
#     212     """
#     213     Desc:
#     214         #individual dift comparison easting
#    (...)
#     217     Output:
#     218     """
# --> 219     self.plot_fig_3D(x = [self.df_sim.index.to_list(),
#     220                        self.df_ED.index.to_list()],
#     221                   y = [self.df_sim.drift_individual_e.to_list(),
#     222                        self.df_ED.drift_individual_e.to_list()],
#     223                   line_label = ["Simulated \nIndividual \nEasting Drifts",
#     224                                 "Detected \nIndividual \nEasting Drifts"],
#     225                   x_label = "Epoch",
#     226                   y_label = "Drift (m)",
#     227                   title = "Simulated vs. Detected Individual Easting Drifts",
#     228                  aspect = False,
#     229                  anchor = 1.25)
#     231     return self.convert_to_png()
#
# File ~\Winter2022\Software_Build\ENGO-500\basePlot.py:80, in BasePlot.plot_fig_3D(self, x, y, line_label, x_label, y_label, title, aspect, anchor, alpha)
#      77 self.set_parameters(ax, x_label, y_label, title, aspect = aspect)
#      79 for i in range(len(x)):
# ---> 80     ax.plot3D(x[i],y[i], offsets[i], label = line_label[i])
#      83 plt.subplots_adjust(left=0, bottom=0, right=1, top=1, wspace=0, hspace=0)
#      85 # Set plot limits
#      86 #plt.xlim(0, 12)
#      87 #plt.ylim(0, 12)
#
# File ~\Anaconda3\envs\capstone\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py:1495, in Axes3D.plot(self, xs, ys, zdir, *args, **kwargs)
#    1492     zs = kwargs.pop('zs', 0)
#    1494 # Match length
# -> 1495 zs = np.broadcast_to(zs, np.shape(xs))
#    1497 lines = super().plot(xs, ys, *args, **kwargs)
#    1498 for line in lines:
#
# File <__array_function__ internals>:5, in broadcast_to(*args, **kwargs)
#
# File ~\Anaconda3\envs\capstone\lib\site-packages\numpy\lib\stride_tricks.py:411, in broadcast_to(array, shape, subok)
#     366 @array_function_dispatch(_broadcast_to_dispatcher, module='numpy')
#     367 def broadcast_to(array, shape, subok=False):
#     368     """Broadcast an array to a new shape.
#     369
#     370     Parameters
#    (...)
#     409            [1, 2, 3]])
#     410     """
# --> 411     return _broadcast_to(array, shape, subok=subok, readonly=True)
#
# File ~\Anaconda3\envs\capstone\lib\site-packages\numpy\lib\stride_tricks.py:348, in _broadcast_to(array, shape, subok, readonly)
#     345     raise ValueError('all elements of broadcast shape must be non-'
#     346                      'negative')
#     347 extras = []
# --> 348 it = np.nditer(
#     349     (array,), flags=['multi_index', 'refs_ok', 'zerosize_ok'] + extras,
#     350     op_flags=['readonly'], itershape=shape, order='C')
#     351 with it:
#     352     # never really has writebackifcopy semantics
#     353     broadcast = it.itviews[0]
#
# ValueError: operands could not be broadcast together with remapped shapes [original->remapped]: (2,)  and requested shape (40,)

# %%
manager.plot_a()
manager.plot_b()
manager.plot_c()
manager.plot_d()
manager.plot_e()
manager.plot_f()
#manager.df_sim

# %%
manager.plot_b()

# %%
manager.Sim.single_pass.columns
# Out:
# Index(['color', 'geometry', 'title'], dtype='object')

# %%
manager.Sim.double_pass.plot()
# Out:
# <AxesSubplot:>

# %%
manager.Sim.temp.plot()
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
#manager.Sim.inner.plot(ax=ax)
manager.Sim.inner_gdf.plot(ax=ax, color='#49e37c')
#manager.Sim.temp.plot(ax=ax, color='red')
manager.Sim.zero_pass.plot(ax=ax)
manager.Sim.single_pass.plot(ax=ax, color = '#915ebd')
manager.Sim.double_pass.plot(ax=ax, color = '#bd7b5e')
# Out:
# <AxesSubplot:>

# %%
manager.Sim.inner_gdf.plot()
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt

x_label="x_label"
y_label="y_label"
title="title"

fig, ax = plt.subplots()

fig.patch.set_facecolor('xkcd:mint green')


ax.set_ylabel(y_label)
ax.set_xlabel(x_label)
ax.set_title(title)

ax.set_facecolor("yellow")

manager.Sim.T_gdf_pt.plot(ax=ax)
manager.Sim.R_gdf_pt.plot(ax=ax)

plt.subplots_adjust(left=0, bottom=0, right=1, top=1, wspace=0, hspace=0)

legend = plt.legend(frameon = 1)
frame = legend.get_frame()
frame.set_facecolor('purple')
frame.set_edgecolor('white')
frame.set_linewidth(0)
        
plt.show()
        

        ##ax.set_aspect('equal')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 18>()
#      14 ax.set_title(title)
#      16 ax.set_facecolor("yellow")
# ---> 18 manager.Sim.T_gdf_pt.plot(ax=ax)
#      19 manager.Sim.R_gdf_pt.plot(ax=ax)
#      21 plt.subplots_adjust(left=0, bottom=0, right=1, top=1, wspace=0, hspace=0)
#
# NameError: name 'manager' is not defined

# %%
from manager import Manager

manager = Manager()
sim = manager.Sim
df = sim.output_tracks

# %%
# Out:
# 20

# %%
from positionGenerator import PositionGenerator as PG
from point import Coord
pg = PG(Coord(.2,.2,std = [0, 0]))

# %%
pg.generate_one()
pg.unique_pnt
# Out:
# [0.2, 0.2]

# %%
from random import randint

for i in range(100):
    print(randint(1,5))
# Out:
# 3
# 5
# 1
# 4
# 2
# 2
# 1
# 4
# 4
# 2
# 3
# 4
# 3
# 1
# 2
# 1
# 5
# 4
# 2
# 3
# 5
# 1
# 1
# 3
# 3
# 3
# 3
# 4
# 1
# 2
# 1
# 3
# 3
# 4
# 3
# 1
# 3
# 4
# 4
# 4
# 3
# 5
# 3
# 2
# 2
# 3
# 5
# 4
# 2
# 3
# 2
# 2
# 5
# 1
# 4
# 5
# 5
# 5
# 4
# 5
# 5
# 3
# 1
# 3
# 2
# 5
# 3
# 1
# 2
# 1
# 5
# 5
# 1
# 1
# 3
# 4
# 4
# 2
# 5
# 4
# 1
# 3
# 4
# 3
# 2
# 3
# 3
# 4
# 1
# 3
# 1
# 2
# 1
# 1
# 2
# 5
# 5
# 2
# 2
# 2
