# %%
import os

# %% [markdown]
# ## Point Class
# Base Case Function Calls
#
# #### Class Functions:
# init() | H() | E() | N() | twoD() | threeD()

# %%
from classes import *

# Create default point for test case
e = 10
n = 5
h = 0
std = [1,1] 
inProj = "E_N"
outProj = "E_N"

p = Point(e, n, h, std, inProj, outProj)


def check_type_value_of_E(p, e):
    """
    Desc: Test type and value for point Easting
    Input: point object p, easting e
    Output: returns T/F df for type and value test
    """
    
    # Pass condition
    if type(p.E()) == type(e) and p.E() == e:
        check = [1, 1]
        print("check_type_value_of_E PASS")
    
    # Type error
    elif type(p.E()) != type(e) and p.E() == e:
        check = [0, 1]
        print("Error in E type")
    
    # Value error
    elif type(p.E()) == type(e) and p.E() != e:
        check = [1, 0]
        print("Error in E value")
    
    else:
        check = [0, 0]
        print(("check_type_value_of_E FAIL"))
        
    return(check)       


def check_type_value_of_N(p, n):
    """
    Desc: Test type and value for point Northing
    Input: point object p, northing n
    Output: prints result of test
    """
    # Pass condition
    if type(p.N()) == type(n) and p.N() == n:
        print("check_type_value_of_N PASS")
    
    # Type error
    elif type(p.N()) != type(n) and p.N() == n:
        print("Error in N type")
    
    # Value error
    elif type(p.N()) == type(n) and p.N() != n:
        print("Error in N value")
    
    else:
        print(("check_type_value_of_N FAIL"))
        

def check_type_value_of_H(p, h):
    """
    Desc: Test type and value for point height 
    Input: point object p, height h
    Output: prints result of test
    """
    # Pass condition
    if type(p.H()) == type(h) and p.h() == h:
        print("check_type_value_of_H PASS")
    
    # Type error
    elif type(p.H()) != type(h) and p.H() == h:
        print("Error in H type")
    
    # Value error
    elif type(p.H()) == type(h) and p.H() != h:
        print("Error in H value")
    
    else:
        print(("check_type_value_of_H FAIL"))
    
    
#def test_point_twoD(p, E, N):
    """
    Desc: Test return values for point function twoD
    Input: point object p, easting E, northing N
    Output: prints result of test
    """
    # Retreive p coords
 #   E_N = p.twoD()
    
    # Test return values
  #  check_type_value_of_N( )
# Out:
# '\n~*~*~*~ May want to output bools rather than print for more usability ~*~*~*~*~\n'

# %% [markdown]
# ## PositionGenerator Class
# Base Case Function Calls
#
# #### Class Functions:
# init() | generate() | plot()

# %%
# %matplotlib inline

from classes import *

PG = PositionGenerator(count = 500)
PG.plot(pick_one = True)

# %% [markdown]
# ## Operator Class
# Base Case Function Calls
#
# #### Class Functions:
# init() | dot() | length() | vector() | unit() | distance() | scale() | add()

# %% [markdown]
# ## Vector Class
# Base Case Function Calls
#
# #### Class Functions:
# init() | pnt2line() | prepare_lines() | plot)pnt2line()

# %%
from Classes.classes import *

v = Vector()
v.pnt2line()
v.plot_pnt2line()
