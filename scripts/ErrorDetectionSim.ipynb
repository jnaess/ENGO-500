# %%
from classes import *
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np

E_T = 5670528.276
N_T = 707668.834
            
#rtk
df = pd.read_csv("rtk.csv")
ED = ErrorDetector(df, E_T, N_T)
        
ED.generate_error_dataframe()        

ED.drift_df.to_csv("rtk_drift2.csv")
ED.jump_df.to_csv("rtk_jump2.csv")
ED.errors_df.to_csv("rtk_errors2.csv")

#psr
#df2 = pd.read_csv("psr.csv")
#ED1 = ErrorDetector(df2, E_T, N_T)
        
#ED1.generate_error_dataframe()        

#ED1.drift_df.to_csv("psr_drift.csv")
#ED1.jump_df.to_csv("psr_jump.csv")
#ED1.errors_df.to_csv("psr_errors.csv")

#ppp
#df3 = pd.read_csv("ppp.csv")
#ED2 = ErrorDetector(df, E_T, N_T)
        
#ED2.generate_error_dataframe()        

#ED2.drift_df.to_csv("ppp_drift.csv")
#ED2.jump_df.to_csv("ppp_jump.csv")
#ED2.errors_df.to_csv("ppp_errors.csv")
# Out:
# C:\Users\Jan Erik Naess\AppData\Local\Temp\ipykernel_25404\3127241423.py:13: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("rtk.csv")
# Epochs Processed: 62436:  72%|████████████████████████████████████              | 62435/86675 [01:34<00:38, 636.34it/s]

# %%
# Out:
# 2

# %%
ED.generate_error_dataframe()

# %%
ED.drift_df.to_csv("rtk_drift.csv")
ED.jump_df.to_csv("rtk_jump.csv")
ED.errors_df.to_csv("rtk_errors.csv")

# %%
df = pd.concat([ED.data,ED.drift_df,ED.jump_df,ED.errors_df], axis=0, ignore_index=True)

# %%
df.to_csv("rtk_errors.csv")
