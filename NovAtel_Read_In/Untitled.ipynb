# %%
from tqdm import tnrange, tqdm
from time import sleep
for i in tqdm(range(4), desc='1st loop'):
    for j in tqdm(range(100), desc='2nd loop', leave=False):
        sleep(0.01)
# Out:
# 1st loop:   0%|          | 0/4 [00:00<?, ?it/s]
# 2nd loop:   0%|          | 0/100 [00:00<?, ?it/s]
# 2nd loop:   6%|▌         | 6/100 [00:00<00:01, 57.38it/s]
# 2nd loop:  12%|█▏        | 12/100 [00:00<00:01, 54.85it/s]
# 2nd loop:  18%|█▊        | 18/100 [00:00<00:01, 54.27it/s]
# 2nd loop:  25%|██▌       | 25/100 [00:00<00:01, 57.41it/s]
# 2nd loop:  32%|███▏      | 32/100 [00:00<00:01, 59.11it/s]
# 2nd loop:  39%|███▉      | 39/100 [00:00<00:01, 60.12it/s]
# 2nd loop:  46%|████▌     | 46/100 [00:00<00:00, 58.03it/s]
# 2nd loop:  53%|█████▎    | 53/100 [00:00<00:00, 57.99it/s]
# 2nd loop:  59%|█████▉    | 59/100 [00:01<00:00, 57.81it/s]
# 2nd loop:  66%|██████▌   | 66/100 [00:01<00:00, 59.12it/s]
# 2nd loop:  73%|███████▎  | 73/100 [00:01<00:00, 60.02it/s]
# 2nd loop:  80%|████████  | 80/100 [00:01<00:00, 59.37it/s]
# 2nd loop:  86%|████████▌ | 86/100 [00:01<00:00, 58.80it/s]
# 2nd loop:  92%|█████████▏| 92/100 [00:01<00:00, 58.44it/s]
# 2nd loop:  99%|█████████▉| 99/100 [00:01<00:00, 59.67it/s]
# 1st loop:  25%|██▌       | 1/4 [00:01<00:05,  1.72s/it]
# 2nd loop:   0%|          | 0/100 [00:00<?, ?it/s]
# 2nd loop:   6%|▌         | 6/100 [00:00<00:01, 57.69it/s]
# 2nd loop:  12%|█▏        | 12/100 [00:00<00:01, 57.70it/s]
# 2nd loop:  19%|█▉        | 19/100 [00:00<00:01, 59.87it/s]
# 2nd loop:  25%|██▌       | 25/100 [00:00<00:01, 58.86it/s]
# 2nd loop:  32%|███▏      | 32/100 [00:00<00:01, 60.14it/s]
# 2nd loop:  39%|███▉      | 39/100 [00:00<00:01, 60.93it/s]
# 2nd loop:  46%|████▌     | 46/100 [00:00<00:00, 61.45it/s]
# 2nd loop:  53%|█████▎    | 53/100 [00:00<00:00, 61.79it/s]
# 2nd loop:  60%|██████    | 60/100 [00:00<00:00, 61.89it/s]
# 2nd loop:  67%|██████▋   | 67/100 [00:01<00:00, 61.90it/s]
# 2nd loop:  74%|███████▍  | 74/100 [00:01<00:00, 62.01it/s]
# 2nd loop:  81%|████████  | 81/100 [00:01<00:00, 62.16it/s]
# 2nd loop:  88%|████████▊ | 88/100 [00:01<00:00, 62.26it/s]
# 2nd loop:  95%|█████████▌| 95/100 [00:01<00:00, 62.34it/s]
# 1st loop:  50%|█████     | 2/4 [00:03<00:03,  1.67s/it]
# 2nd loop:   0%|          | 0/100 [00:00<?, ?it/s]
# 2nd loop:   6%|▌         | 6/100 [00:00<00:01, 57.70it/s]
# 2nd loop:  12%|█▏        | 12/100 [00:00<00:01, 55.12it/s]
# 2nd loop:  19%|█▉        | 19/100 [00:00<00:01, 58.41it/s]
# 2nd loop:  26%|██▌       | 26/100 [00:00<00:01, 59.92it/s]
# 2nd loop:  33%|███▎      | 33/100 [00:00<00:01, 60.77it/s]
# 2nd loop:  40%|████      | 40/100 [00:00<00:00, 61.31it/s]
# 2nd loop:  47%|████▋     | 47/100 [00:00<00:00, 61.54it/s]
# 2nd loop:  54%|█████▍    | 54/100 [00:00<00:00, 59.04it/s]
# 2nd loop:  61%|██████    | 61/100 [00:01<00:00, 59.98it/s]
# 2nd loop:  68%|██████▊   | 68/100 [00:01<00:00, 60.68it/s]
# 2nd loop:  75%|███████▌  | 75/100 [00:01<00:00, 61.10it/s]
# 2nd loop:  82%|████████▏ | 82/100 [00:01<00:00, 61.40it/s]
# 2nd loop:  89%|████████▉ | 89/100 [00:01<00:00, 61.68it/s]
# 2nd loop:  96%|█████████▌| 96/100 [00:01<00:00, 61.85it/s]
# 1st loop:  75%|███████▌  | 3/4 [00:05<00:01,  1.66s/it]
# 2nd loop:   0%|          | 0/100 [00:00<?, ?it/s]
# 2nd loop:   7%|▋         | 7/100 [00:00<00:01, 62.26it/s]
# 2nd loop:  14%|█▍        | 14/100 [00:00<00:01, 62.26it/s]
# 2nd loop:  21%|██        | 21/100 [00:00<00:01, 62.28it/s]
# 2nd loop:  28%|██▊       | 28/100 [00:00<00:01, 62.04it/s]
# 2nd loop:  35%|███▌      | 35/100 [00:00<00:01, 62.08it/s]
# 2nd loop:  42%|████▏     | 42/100 [00:00<00:00, 62.02it/s]
# 2nd loop:  49%|████▉     | 49/100 [00:00<00:00, 62.10it/s]
# 2nd loop:  56%|█████▌    | 56/100 [00:00<00:00, 62.11it/s]
# 2nd loop:  63%|██████▎   | 63/100 [00:01<00:00, 62.13it/s]
# 2nd loop:  70%|███████   | 70/100 [00:01<00:00, 58.19it/s]
# 2nd loop:  76%|███████▌  | 76/100 [00:01<00:00, 57.99it/s]
# 2nd loop:  83%|████████▎ | 83/100 [00:01<00:00, 59.29it/s]
# 2nd loop:  90%|█████████ | 90/100 [00:01<00:00, 58.84it/s]
# 2nd loop:  97%|█████████▋| 97/100 [00:01<00:00, 59.77it/s]
# 1st loop: 100%|██████████| 4/4 [00:06<00:00,  1.66s/it]
