# %%
#pip install -r requirements.txt

#______________git commands_______________
#git add *
#git commit -m "type message in string here"
#git push
#git pull

# %%
from classes import *

import numpy as np
from pyproj import Proj, transform
import pandas as pd
import matplotlib.pyplot as plt

dat = Data()

# %%
#convert the first 100 into desired coorinates
lat, lon = dat.convert(dat.rtk["lat"][:100],dat.rtk["lon"][:100])
# Out:
# C:\Users\Jan Erik Naess\Anaconda3\envs\ensf411\lib\site-packages\pyproj\crs\crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# C:\Users\Jan Erik Naess\Anaconda3\envs\ensf411\lib\site-packages\pyproj\crs\crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
lat, lon = dat.convert(dat.rtk["lat"][100:200],dat.rtk["lon"][100:200])
#list(dat.rtk["lat"][100:200])
# Out:
# C:\Users\Jan Erik Naess\Anaconda3\envs\ensf411\lib\site-packages\pyproj\crs\crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# C:\Users\Jan Erik Naess\Anaconda3\envs\ensf411\lib\site-packages\pyproj\crs\crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
plt.plot(lat,lon)

# %%
plt.scatter(lat,lon)

# %%
dat.rtk
# Out:
#              sol_sattus pos_type             lat               lon        hgt  \
# 0      INSUFFICIENT_OBS     NONE   0.00000000000     0.00000000000     0.0000
# 1      INSUFFICIENT_OBS     NONE   0.00000000000     0.00000000000     0.0000
# 2      INSUFFICIENT_OBS     NONE   0.00000000000     0.00000000000     0.0000
# 3      INSUFFICIENT_OBS     NONE   0.00000000000     0.00000000000     0.0000
# 4      INSUFFICIENT_OBS     NONE   0.00000000000     0.00000000000     0.0000
# ...                 ...      ...             ...               ...        ...
# 86710      SOL_COMPUTED  PSRDIFF  51.15043875923  -114.03068094053  1097.6883
# 86711      SOL_COMPUTED  PSRDIFF  51.15043876321  -114.03068094201  1097.6885
# 86712      SOL_COMPUTED  PSRDIFF  51.15043876119  -114.03068103272  1097.6952
# 86713      SOL_COMPUTED  PSRDIFF  51.15043880698  -114.03068100445  1097.6945
# 86714      SOL_COMPUTED  PSRDIFF  51.15043886020  -114.03068105503  1097.7070
#
#       undulation datum id#   lat σ   lon σ   hgt σ  ... diff_age sol_age #SVs  \
# 0         0.0000     WGS84  0.0000  0.0000  0.0000  ...    0.000   0.000    0
# 1         0.0000     WGS84  0.0000  0.0000  0.0000  ...    0.000   0.000    0
# 2         0.0000     WGS84  0.0000  0.0000  0.0000  ...    0.000   0.000    0
# 3         0.0000     WGS84  0.0000  0.0000  0.0000  ...    0.000   0.000    0
# 4         0.0000     WGS84  0.0000  0.0000  0.0000  ...    0.000   0.000    0
# ...          ...       ...     ...     ...     ...  ...      ...     ...  ...
# 86710   -17.0000     WGS84  0.3158  0.2584  0.4915  ...    2.000   0.000   42
# 86711   -17.0000     WGS84  0.3136  0.2570  0.4888  ...    2.000   0.000   42
# 86712   -17.0000     WGS84  0.3135  0.2568  0.4886  ...    2.000   0.000   42
# 86713   -17.0000     WGS84  0.3133  0.2566  0.4882  ...    2.000   0.000   42
# 86714   -17.0000     WGS84  0.3136  0.2570  0.4888  ...    2.000   0.000   41
#
#       #solnSVs #ggL1 #solnMultiSVs Null ext sol stat  \
# 0            0     0             0   00           00
# 1            0     0             0   00           00
# 2            0     0             0   00           00
# 3            0     0             0   00           00
# 4            0     0             0   00           00
# ...        ...   ...           ...  ...          ...
# 86710       37     0             0   00           08
# 86711       37     0             0   00           08
# 86712       37     0             0   00           08
# 86713       37     0             0   00           08
# 86714       37     0             0   00           08
#
#       Galileo and BeiDou sig mask GPS and GLONASS sig mask
# 0                              00              00*9fd2efb6
# 1                              00              00*30b81b98
# 2                              00              00*e71e4c30
# 3                              00              00*9dd33469
# 4                              00              00*621eb137
# ...                           ...                      ...
# 86710                          11              11*b76efc59
# 86711                          11              11*4501bfb4
# 86712                          11              11*80892cb4
# 86713                          11              11*f12aca38
# 86714                          11              11*9e0c0be6
#
# [86715 rows x 21 columns]
