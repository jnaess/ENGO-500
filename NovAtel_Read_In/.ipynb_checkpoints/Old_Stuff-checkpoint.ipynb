# %%
import numpy as np
from sys import argv

#path = str(argv[1])
x = np.fromfile("binaryFile.bin", dtype=int)
print("X: {} Value: {}".format(x, type(x)))
x
# Out:
# X: [ 0  1  3  6 10 15 21 28 36 45] Value: <class 'numpy.ndarray'>
# array([ 0,  1,  3,  6, 10, 15, 21, 28, 36, 45])

# %%
x = np.fromfile("Rooftop_Position_Logs (1).GPS")
type(x)
# Out:
# numpy.ndarray

# %%
import pandas as pd
x = np.fromfile("Rooftop_Position_Logs.BIN")
x
# Out:
# array([ 1.49186888e-154,  1.09473763e-310,  1.54921331e-220, ...,
#         2.00000000e+000,  2.01865460e-310, -5.33876230e+176])

# %%
# Out:
# #RTKPOSA,COM1,0,19.5,UNKNOWN,0,2.000,124c0000,69d3,16725;INSUFFICIENT_OBS,NONE,0.00000000000,0.00000000000,0.0000,0.0000,WGS84,0.0000,0.0000,0.0000,"",0.000,0.000,0,0,0,0,00,00,00,00*9fd2efb6

# %%
# Out:
#      sol_sattus pos_type             lat               lon        hgt  \
# 0  SOL_COMPUTED  PSRDIFF  51.15043751292  -114.03067768438  1097.1240
#
#   undulation datum id#   lat σ   lon σ   hgt σ  ... diff_age sol_age #SVs  \
# 0   -17.0000     WGS84  0.3335  0.2542  0.5266  ...    2.000   0.000   38
#
#   #solnSVs #ggL1 #solnMultiSVs Null ext sol stat Galileo and BeiDou sig mask  \
# 0       33     0             0   00           08                          11
#
#   GPS and GLONASS sig mask
# 0              11*4b7e8d04
#
# [1 rows x 21 columns]

# %%
# Out:
# C:\Users\Jan Erik Naess\Anaconda3\envs\ensf411\lib\site-packages\pyproj\crs\crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# C:\Users\Jan Erik Naess\Anaconda3\envs\ensf411\lib\site-packages\pyproj\crs\crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# ...

# %%
# Out:
# 700729.7313162811
# 5662809.719125882

# %%
#convert the first 100 into desired coorinates
lat, lon = dat.convert(dat.rtk["lat"][:100],dat.rtk["lon"][:100])
# Out:
# C:\Users\Jan Erik Naess\Anaconda3\envs\ensf411\lib\site-packages\pyproj\crs\crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# C:\Users\Jan Erik Naess\Anaconda3\envs\ensf411\lib\site-packages\pyproj\crs\crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# ...

# %%
lat, lon = dat.convert(dat.rtk["lat"][100:200],dat.rtk["lon"][100:200])
#list(dat.rtk["lat"][100:200])
# Out:
# C:\Users\Jan Erik Naess\Anaconda3\envs\ensf411\lib\site-packages\pyproj\crs\crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# C:\Users\Jan Erik Naess\Anaconda3\envs\ensf411\lib\site-packages\pyproj\crs\crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(lat,lon)

# %%
from novAtelClasses import *

dat = Data()
# Out:
#              sol_sattus    pos_type             lat               lon  \
# 0      INSUFFICIENT_OBS        NONE   0.00000000000     0.00000000000
# 1      INSUFFICIENT_OBS        NONE   0.00000000000     0.00000000000
# 2      INSUFFICIENT_OBS        NONE   0.00000000000     0.00000000000
# 3      INSUFFICIENT_OBS        NONE   0.00000000000     0.00000000000
# 4      INSUFFICIENT_OBS        NONE   0.00000000000     0.00000000000
# ...                 ...         ...             ...               ...
# 86709      SOL_COMPUTED  NARROW_INT  51.15043742628  -114.03067811855
# 86710      SOL_COMPUTED         PPP  51.15043707574  -114.03067871024
# 86711      SOL_COMPUTED         PPP  51.15043706675  -114.03067872928
# 86712      SOL_COMPUTED         PPP  51.15043706177  -114.03067872544
# 86713      SOL_COMPUTED         PPP  51.15043707823  -114.03067873234
#
#              hgt undulation datum_id# lat_sigma lon_sigma hgt_sigma  ...  \
# ...

# %%
dat.psr
# Out:
#              sol_sattus    pos_type             lat               lon  \
# 0      INSUFFICIENT_OBS        NONE   0.00000000000     0.00000000000
# 1      INSUFFICIENT_OBS        NONE   0.00000000000     0.00000000000
# 2      INSUFFICIENT_OBS        NONE   0.00000000000     0.00000000000
# 3      INSUFFICIENT_OBS        NONE   0.00000000000     0.00000000000
# 4      INSUFFICIENT_OBS        NONE   0.00000000000     0.00000000000
# ...                 ...         ...             ...               ...
# 86709      SOL_COMPUTED         PPP  51.15043705242  -114.03067870992
# 86710      SOL_COMPUTED  NARROW_INT  51.15043746657  -114.03067811795
# 86711      SOL_COMPUTED  NARROW_INT  51.15043743780  -114.03067813308
# 86712      SOL_COMPUTED  NARROW_INT  51.15043743917  -114.03067812550
# 86713      SOL_COMPUTED  NARROW_INT  51.15043747026  -114.03067813387
#
#              hgt undulation datum id# lat_sigma lon_sigma hgt_sigma  ...  \
# ...
