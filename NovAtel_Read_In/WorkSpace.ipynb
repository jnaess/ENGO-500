# %%
#pip install -r requirements.txt

#______________git commands_______________
#git add *
#git commit -m "type message in string here"
#git push
#git pull

# %%
from classes import *

import numpy as np
from pyproj import Proj, transform
import pandas as pd
import matplotlib.pyplot as plt

dat = Data()

# %%
#convert the first 100 into desired coorinates
lat, lon = dat.convert(dat.rtk["lat"][:100],dat.rtk["lon"][:100])
# Out:
# C:\Users\Jan Erik Naess\Anaconda3\envs\capstone\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# C:\Users\Jan Erik Naess\Anaconda3\envs\capstone\lib\site-packages\pyproj\crs\crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# ---------------------------------------------------------------------------
# CRSError                                  Traceback (most recent call last)
# Input In [5], in <cell line: 2>()
#       1 #convert the first 100 into desired coorinates
# ----> 2 lat, lon = dat.convert(dat.rtk["lat"][:100],dat.rtk["lon"][:100])
#
# File ~\Winter2022\Software_Build\ENGO-500\NovAtel_Read_In\data.py:107, in Data.convert(self, lat, lon, in_proj, out_proj)
#     103 new_lon = []
#     105 if len(lat) == len(lon) and len(lat) > 0:
#     106     #then these are conditions that we can convert in
# --> 107     inProj = Proj(init=in_proj)
#     108     outProj = Proj(init=out_proj)
#     110     for i in range(len(lat)):
#
# File ~\Anaconda3\envs\capstone\lib\site-packages\pyproj\proj.py:107, in Proj.__init__(self, projparams, preserve_units, **kwargs)
#      45 def __init__(
#      46     self, projparams: Any = None, preserve_units: bool = True, **kwargs
#      47 ) -> None:
#      48     """
#      49     A Proj class instance is initialized with proj map projection
#      50     control parameter key/value pairs. The key/value pairs can
#    (...)
#     105     '116.366 39.867'
#     106     """
# --> 107     self.crs = CRS.from_user_input(projparams, **kwargs)
#     108     # make sure units are meters if preserve_units is False.
#     109     if not preserve_units and "foot" in self.crs.axis_info[0].unit_name:
#     110         # ignore export to PROJ string deprecation warning
#
# File ~\Anaconda3\envs\capstone\lib\site-packages\pyproj\crs\crs.py:440, in CRS.from_user_input(value, **kwargs)
#     438 if isinstance(value, CRS):
#     439     return value
# --> 440 return CRS(value, **kwargs)
#
# File ~\Anaconda3\envs\capstone\lib\site-packages\pyproj\crs\crs.py:296, in CRS.__init__(self, projparams, **kwargs)
#     293     projkwargs = _prepare_from_dict(kwargs, allow_json=False)
#     294     projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# --> 296 super().__init__(projstring)
#
# File pyproj/_crs.pyx:2338, in pyproj._crs._CRS.__init__()
#
# CRSError: Invalid projection: +init=epsg:3780 +type=crs: (Internal Proj Error: proj_create: SQLite error on SELECT name, coordinate_system_auth_name, coordinate_system_code, geodetic_crs_auth_name, geodetic_crs_code, conversion_auth_name, conversion_code, area_of_use_auth_name, area_of_use_code, text_definition, deprecated FROM projected_crs WHERE auth_name = ? AND code = ?: no such column: area_of_use_auth_name)

# %%
lat, lon = dat.convert(dat.rtk["lat"][100:200],dat.rtk["lon"][100:200])
#list(dat.rtk["lat"][100:200])
# Out:
# C:\Users\Jan Erik Naess\Anaconda3\envs\ensf411\lib\site-packages\pyproj\crs\crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# C:\Users\Jan Erik Naess\Anaconda3\envs\ensf411\lib\site-packages\pyproj\crs\crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
plt.plot(lat,lon)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 plt.title("Title");
#       2 plt.plot(lat,lon)
#
# NameError: name 'plt' is not defined

# %%
plt.scatter(lat,lon)

# %%
dat.rtk
# Out:
#              sol_sattus pos_type             lat               lon        hgt  \
# 0      INSUFFICIENT_OBS     NONE   0.00000000000     0.00000000000     0.0000
# 1      INSUFFICIENT_OBS     NONE   0.00000000000     0.00000000000     0.0000
# 2      INSUFFICIENT_OBS     NONE   0.00000000000     0.00000000000     0.0000
# 3      INSUFFICIENT_OBS     NONE   0.00000000000     0.00000000000     0.0000
# 4      INSUFFICIENT_OBS     NONE   0.00000000000     0.00000000000     0.0000
# ...                 ...      ...             ...               ...        ...
# 86710      SOL_COMPUTED  PSRDIFF  51.15043875923  -114.03068094053  1097.6883
# 86711      SOL_COMPUTED  PSRDIFF  51.15043876321  -114.03068094201  1097.6885
# 86712      SOL_COMPUTED  PSRDIFF  51.15043876119  -114.03068103272  1097.6952
# 86713      SOL_COMPUTED  PSRDIFF  51.15043880698  -114.03068100445  1097.6945
# 86714      SOL_COMPUTED  PSRDIFF  51.15043886020  -114.03068105503  1097.7070
#
#       undulation datum id#   lat σ   lon σ   hgt σ  ... diff_age sol_age #SVs  \
# 0         0.0000     WGS84  0.0000  0.0000  0.0000  ...    0.000   0.000    0
# 1         0.0000     WGS84  0.0000  0.0000  0.0000  ...    0.000   0.000    0
# 2         0.0000     WGS84  0.0000  0.0000  0.0000  ...    0.000   0.000    0
# 3         0.0000     WGS84  0.0000  0.0000  0.0000  ...    0.000   0.000    0
# 4         0.0000     WGS84  0.0000  0.0000  0.0000  ...    0.000   0.000    0
# ...          ...       ...     ...     ...     ...  ...      ...     ...  ...
# 86710   -17.0000     WGS84  0.3158  0.2584  0.4915  ...    2.000   0.000   42
# 86711   -17.0000     WGS84  0.3136  0.2570  0.4888  ...    2.000   0.000   42
# 86712   -17.0000     WGS84  0.3135  0.2568  0.4886  ...    2.000   0.000   42
# 86713   -17.0000     WGS84  0.3133  0.2566  0.4882  ...    2.000   0.000   42
# 86714   -17.0000     WGS84  0.3136  0.2570  0.4888  ...    2.000   0.000   41
#
#       #solnSVs #ggL1 #solnMultiSVs Null ext sol stat  \
# 0            0     0             0   00           00
# 1            0     0             0   00           00
# 2            0     0             0   00           00
# 3            0     0             0   00           00
# 4            0     0             0   00           00
# ...        ...   ...           ...  ...          ...
# 86710       37     0             0   00           08
# 86711       37     0             0   00           08
# 86712       37     0             0   00           08
# 86713       37     0             0   00           08
# 86714       37     0             0   00           08
#
#       Galileo and BeiDou sig mask GPS and GLONASS sig mask
# 0                              00              00*9fd2efb6
# 1                              00              00*30b81b98
# 2                              00              00*e71e4c30
# 3                              00              00*9dd33469
# 4                              00              00*621eb137
# ...                           ...                      ...
# 86710                          11              11*b76efc59
# 86711                          11              11*4501bfb4
# 86712                          11              11*80892cb4
# 86713                          11              11*f12aca38
# 86714                          11              11*9e0c0be6
#
# [86715 rows x 21 columns]
