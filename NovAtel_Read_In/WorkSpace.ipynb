# %%
#pip install -r requirements.txt

#______________git commands_______________
#git add *
#git commit -m "type message in string here"
#git push
#git pull

# %%
from classes import *

import numpy as np
from pyproj import Proj, transform
import pandas as pd
import matplotlib.pyplot as plt

dat = Data()

# %%
dat.add_to_csv()

# %%
#convert the first 100 into desired coorinates
lat, lon = dat.convert(dat.rtk["lat"][:100],dat.rtk["lon"][:100])

# %%
lat, lon = dat.convert(dat.rtk["lat"][100:200],dat.rtk["lon"][100:200])
#list(dat.rtk["lat"][100:200])

# %%
plt.plot(lat,lon)
plt.title('Collected Data')
plt.xlabel('Longitude')
plt.ylabel('Lattitude')
# Out:
# Text(0, 0.5, 'Lattitude')

# %%
plt.scatter(lat,lon)

# %%
psr_clean = dat.psr.drop(dat.psr[dat.psr.sol_sattus == "INSUFFICIENT_OBS"].index)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13784/1820747209.py in <module>
# ----> 1 psr_clean = dat.psr.drop(dat.psr[dat.psr.sol_sattus == "INSUFFICIENT_OBS"].index)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'sol_sattus'

# %%
dat.psr.sol_sattus == "INSUFFICIENT_OBS"

# %%
lat, lon = dat.convert(dat.rtk["lat"],dat.rtk["lon"])
